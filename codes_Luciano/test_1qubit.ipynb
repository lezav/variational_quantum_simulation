# %%
import numpy as np
import matplotlib.pyplot as plt
from qiskit import Aer
from main import *

# %%
simulator = Aer.get_backend('aer_simulator')
shots = 10**5
steps = 10

# %%
R = [ [ 'ry', [0] ] ]
Uk = [ [ 'cy', [0] ] ]
Uq = [ [ 'cy', [0] ], [ 'cy', [0] ]  ]

# %%
circ = circuits( R, Uk, Uq, 1 )

# %%
circ[0].draw(output='mpl')

# %%
circ[1].draw(output='mpl')

# %%
circ_par = [ qc.assign_parameters([0]) for qc in circ  ]
job = simulator.run( circ_par , shots=shots )

# %%
job.result().get_counts()
# Out:
# [{'0': 100000}, {'0': 100000}]

# %%
params = np.zeros(1)
params_evolved = VariationalSimulation( R, Uq, Uk, params, steps, shots )
plt.plot( params_evolved )
# Out:
# [[0.25]] [0.5]
# [[0.25]] [0.5]
# [[0.25]] [0.5]
# [[0.25]] [0.5]
# [[0.25]] [0.5]
# [[0.25]] [0.5]
# [[0.25]] [0.5]
# [[0.25]] [0.5]
# [[0.25]] [0.5]
# [[0.25]] [0.5]
